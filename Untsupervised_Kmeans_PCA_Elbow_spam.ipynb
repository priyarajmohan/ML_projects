# %% [markdown]
# <a href="https://colab.research.google.com/github/priyarajmohan/ML_projects/blob/main/Untsupervised_Kmeans_PCA_Elbow_spam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from scipy.cluster.hierarchy import linkage,dendrogram,fcluster
import matplotlib.pyplot as plt

# %%
spam = pd.read_csv('/content/spambase_csv.csv')

# %%
spam
# Out:
#       word_freq_make  word_freq_address  ...  capital_run_length_total  class
# 0               0.00               0.64  ...                       278      1
# 1               0.21               0.28  ...                      1028      1
# 2               0.06               0.00  ...                      2259      1
# 3               0.00               0.00  ...                       191      1
# 4               0.00               0.00  ...                       191      1
# ...              ...                ...  ...                       ...    ...
# 4596            0.31               0.00  ...                        88      0
# 4597            0.00               0.00  ...                        14      0
# 4598            0.30               0.00  ...                       118      0
# 4599            0.96               0.00  ...                        78      0
# 4600            0.00               0.00  ...                        40      0
#
# [4601 rows x 58 columns]

# %%
spam.isnull().sum()
# Out:
# word_freq_make                0
# word_freq_address             0
# word_freq_all                 0
# word_freq_3d                  0
# word_freq_our                 0
# word_freq_over                0
# word_freq_remove              0
# word_freq_internet            0
# word_freq_order               0
# word_freq_mail                0
# word_freq_receive             0
# word_freq_will                0
# word_freq_people              0
# word_freq_report              0
# word_freq_addresses           0
# word_freq_free                0
# word_freq_business            0
# word_freq_email               0
# word_freq_you                 0
# word_freq_credit              0
# word_freq_your                0
# word_freq_font                0
# word_freq_000                 0
# word_freq_money               0
# word_freq_hp                  0
# word_freq_hpl                 0
# word_freq_george              0
# word_freq_650                 0
# word_freq_lab                 0
# ...

# %%
spam.duplicated().sum()
# Out:
# np.int64(391)

# %%
spam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
for i in spam.columns:
  sc.fit_transform(spam[[i]])

# %%
spam
# Out:
#       word_freq_make  word_freq_address  ...  capital_run_length_total  class
# 0               0.00               0.64  ...                       278      1
# 1               0.21               0.28  ...                      1028      1
# 2               0.06               0.00  ...                      2259      1
# 3               0.00               0.00  ...                       191      1
# 4               0.00               0.00  ...                       191      1
# ...              ...                ...  ...                       ...    ...
# 4596            0.31               0.00  ...                        88      0
# 4597            0.00               0.00  ...                        14      0
# 4598            0.30               0.00  ...                       118      0
# 4599            0.96               0.00  ...                        78      0
# 4600            0.00               0.00  ...                        40      0
#
# [4601 rows x 58 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
x_pca = pca.fit_transform(spam)
x_pca
# Out:
# array([[  -3.7867769 ,    9.4119307 ],
#        [ 742.63220795,  -74.00122296],
#        [2019.85415578,  102.07715318],
#        ...,
#        [-170.64388615,  -18.62981389],
#        [-210.26932829,  -13.08453617],
#        [-247.75502747,   -6.85136671]])

# %%
x_pca
# Out:
# array([[  -3.7867769 ,    9.4119307 ],
#        [ 742.63220795,  -74.00122296],
#        [2019.85415578,  102.07715318],
#        ...,
#        [-170.64388615,  -18.62981389],
#        [-210.26932829,  -13.08453617],
#        [-247.75502747,   -6.85136671]])

# %%
 z = linkage(x_pca,method = 'ward')

# %%
plt.figure(figsize=(8,5))
dendrogram(z)
plt.title('Hierarchicalclustering')
plt.xlabel('sample index')
plt.ylabel('distance')
plt.show()

# %%
clusters = fcluster(z,t=2,criterion = 'maxclust')
plt.scatter(x_pca[:,0],x_pca[:,1],c=clusters,cmap='rainbow')
plt.title('Hierarchical clustering')
plt.xlabel('pca1')
plt.ylabel('pca2')
plt.show()

# %%
#K_MEANS CLUSTERING

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage,dendrogram,fcluster

# %%
wcss = []

# %%
for i in range(1,11):
  K_means = KMeans(n_clusters = i,init = 'k-means++',random_state=42)
  K_means.fit(spam)
  wcss.append(K_means.inertia_)

# %%
wcss
# Out:
# [1870740245.8847759,
#  943480843.9871824,
#  541294153.5032008,
#  468133788.3699114,
#  257777771.43592054,
#  185789047.8322929,
#  151679068.26467162,
#  116695395.48061375,
#  93200011.38689676,
#  77032026.328943,
#  1870740245.8847759,
#  943480843.9871824,
#  541294153.5032008,
#  468133788.3699114,
#  257777771.43592054,
#  185789047.8322929,
#  151679068.26467162,
#  116695395.48061375,
#  93200011.38689676,
#  77032026.328943]

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,11), wcss[:10], marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method For Optimal K')
plt.show()

# %%
model = KMeans(n_clusters = 3,init = 'k-means++',random_state = 42)
y_kmeans = model.fit_predict(spam)
spam['cluster'] = y_kmeans

# %%
spam
# Out:
#       word_freq_make  word_freq_address  ...  class  cluster
# 0               0.00               0.64  ...      1        0
# 1               0.21               0.28  ...      1        1
# 2               0.06               0.00  ...      1        1
# 3               0.00               0.00  ...      1        0
# 4               0.00               0.00  ...      1        0
# ...              ...                ...  ...    ...      ...
# 4596            0.31               0.00  ...      0        0
# 4597            0.00               0.00  ...      0        0
# 4598            0.30               0.00  ...      0        0
# 4599            0.96               0.00  ...      0        0
# 4600            0.00               0.00  ...      0        0
#
# [4601 rows x 59 columns]

# %%
from  sklearn.decomposition import PCA
pca = PCA(n_components = 3)
x_pca = pca.fit_transform(spam)
x_pca
# Out:
# array([[-3.78680320e+00,  9.41192637e+00, -2.24643235e+00],
#        [ 7.42632481e+02, -7.40011860e+01, -5.67470060e-01],
#        [ 2.01985435e+03,  1.02077163e+02, -2.37766151e+01],
#        ...,
#        [-1.70643903e+02, -1.86298146e+01, -5.09844060e-01],
#        [-2.10269342e+02, -1.30845361e+01, -8.82315813e-01],
#        [-2.47755039e+02, -6.85136583e+00, -9.84883259e-01]])

# %%
plt.figure(figsize = (8,5))
sns.scatterplot(x = x_pca[:,0],y = x_pca[:,1],hue = spam['cluster'],palette='tab10',s=100)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/seaborn/palettes.py in color_palette(palette, n_colors, desat, as_cmap)
#     234                 # Perhaps a named matplotlib colormap?
# --> 235                 palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236             except (ValueError, KeyError):  # Error class changed in mpl36
#
# /usr/local/lib/python3.12/dist-packages/seaborn/palettes.py in mpl_palette(name, n_colors, as_cmap)
#     405     else:
# --> 406         cmap = get_colormap(name)
#     407
#
# /usr/local/lib/python3.12/dist-packages/seaborn/_compat.py in get_colormap(name)
#      61     try:
# ---> 62         return mpl.colormaps[name]
#      63     except AttributeError:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cm.py in __getitem__(self, item)
#      97         except KeyError:
# ...
